# %% [markdown]
# Capstone Project - The Battle of Neighbourhoods (Week1)
# ============

# %% [markdown]
# ## Contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# ##### My stakeholders are those who plan to move to new neighbourhood close to the Samsung Digital City in Suwon, South Korea. They work for Samsung Electronics and want to find the best residential district around office. I target to find the optimal house location using the skills that I learned from the IBM Data Science course. Briefly thinking, I should consider some factors below to increase the possibility of business success.
#
#   * 1. Near Samsung Digital City at Suwon
#   * 2. Close to Park or Green place
#   * 3. Easy to access basic amenities

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# ##### I mainly collected two types of data sets using Google geocode API and Foursqure API. First of all, I've got Samsung Digital City (SDC) Neighbourhood data that includes address, latitude, longitude using Google geocode API. Then, I've got Venues data of all neighbourhoods within 20km from SDC using Foursquare API. These two data will be used to analyze and cluster neighbourhoods. And I will finally suggest the best neighbourhood option to people who look for their new house location around SDC.

# %% [markdown]
# 1) Get the location coordinates of Samsung office using Google geocode api.

# %%
import requests
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]

google_api_key = 'AIzaSyBoF5cKq8jauHleQ3YzDalgzrLa9KsOKSg'
address = 'Samsung Digital City, Suwon-si, Gyeonggi-do'
sdc_center = get_coordinates(google_api_key, address)
print('Coordinate of {}: {}'.format(address, sdc_center))
# Out:
# Coordinate of Samsung Digital City, Suwon-si, Gyeonggi-do: [37.2539047, 127.0485106]

# %% [markdown]
# 2) Create neighbourhoods that are equally spaced, centered around Samsung Digital City and within ~20km from Samsung Digital City. Our neighborhoods will be defined as circular areas with a radius of 1000 meters, so our neighborhood centers will be 2km apart. Belows are funtions to create neighbourhoods and their center coordinates (With reference to Notebook: https://cocl.us/coursera_capstone_notebook)

# %%
# !pip install shapely
import shapely.geometry

# !pip install pyproj
import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')
print('Samsung Digital City center longitude={}, latitude={}'.format(sdc_center[1], sdc_center[0]))
x, y = lonlat_to_xy(sdc_center[1], sdc_center[0])
print('Samsung Digital City center UTM X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('SDC center longitude={}, latitude={}'.format(lo, la))
# Out:
# Collecting shapely
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 1.9MB/s eta 0:00:01
# Installing collected packages: shapely
# Successfully installed shapely-1.6.4.post2
# Requirement already satisfied: pyproj in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.9.6)
# Coordinate transformation check
# -------------------------------
# Samsung Digital City center longitude=127.0485106, latitude=37.2539047
# Samsung Digital City center UTM X=6532964.978720854, Y=12918928.066697462
# SDC center longitude=127.04851059999953, latitude=37.25390469999955

# %% [markdown]
# 3) Create neighbourhoods and visualize them in folium map.

# %%
sdc_center_x, sdc_center_y = lonlat_to_xy(sdc_center[1], sdc_center[0]) # City center in Cartesian coordinates

k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = sdc_center_x - 10000
x_step = 1000
y_min = sdc_center_y - 10000 - (int(21/k)*k*1000 - 20000)/2
y_step = 1000 * k 

latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []
for i in range(0, int(21/k)):
    y = y_min + i * y_step
    x_offset = 500 if i%2==0 else 0
    for j in range(0, 21):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(sdc_center_x, sdc_center_y, x, y)
        if (distance_from_center <= 20001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate neighborhood centers generated.')
# Out:
# 504 candidate neighborhood centers generated.

# %%
# !pip install folium

import folium
# Out:
# Requirement already satisfied: folium in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (0.3.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.10.3)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (2.22.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (1.25.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium) (2019.9.11)

# %%
map_sdc = folium.Map(location=sdc_center, zoom_start=12)
folium.Marker(sdc_center, popup='ttt').add_to(map_sdc)
for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_berlin) 
    folium.Circle([lat, lon], radius=500, color='blue', fill=False).add_to(map_sdc)
    #folium.Marker([lat, lon]).add_to(map_suji)
map_sdc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 4) Define the function to create the address of neighbourhoods

# %%
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(google_api_key,sdc_center[0], sdc_center[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(sdc_center[0], sdc_center[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [37.2539047, 127.0485106] is: 416 Sin-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea

# %% [markdown]
# 5) Get the addresses of all neighbourhoods

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', suwon', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
addresses[150:170]
# Out:
# ['506-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea',
#  '807-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea',
#  '1171-1 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea',
#  '산7-5 Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea',
#  '12 Paldalmun-ro 163beon-gil, Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea',
#  '121-10 Jungbu-daero, Ji-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea',
#  '258-1 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea',
#  '899-1 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea',
#  '138-122 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '526-5 Seryu 3(sam)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '546-8 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '1039 Seryu 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '422-9 Jangji-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '334-3 Pyeongni-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '600 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea',
#  '116-1 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea',
#  '457-42 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea',
#  '112-3 Wau-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea',
#  '산66-6 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea',
#  '810 Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea']

# %% [markdown]
# 6) Create Dataframe that includes address, latitudes, longitudes of all neighbourhoods in Sujigu Area (It also includes adjacent neighborhoods of Suji-gu).

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head()
# Out:
#                                              Address   Latitude   Longitude  \
# 0  산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeon...  37.337181  127.022600
# 1  80 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeong...  37.332100  127.018378
# 2  409-25 Sanggwanggyo-dong, Jangan-gu, Suwon, Gy...  37.327020  127.014157
# 3  산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gye...  37.321940  127.009937
# 4  364-1 Pajang-dong, Jangan-gu, Suwon, Gyeonggi-...  37.316861  127.005718
#
#               X             Y  Distance from center
# 0  6.523465e+06  1.290854e+07          14080.127840
# 1  6.524465e+06  1.290854e+07          13425.721582
# 2  6.525465e+06  1.290854e+07          12816.005618
# 3  6.526465e+06  1.290854e+07          12257.650672
# 4  6.527465e+06  1.290854e+07          11757.976016

# %% [markdown]
# 7) Foresquare Credential

# %%
CLIENT_ID = 'FQIQDSZ2JNHV2YB4MGT0DK4SAHODBFZHSLJY35WM4TEQQEAJ' # your Foursquare ID
CLIENT_SECRET = 'THCXEARMB11F2KDNRUDU0GU35PKVT4MVFSP1CAJGWQET1CBP' # your Foursquare Secret
VERSION = '20190605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FQIQDSZ2JNHV2YB4MGT0DK4SAHODBFZHSLJY35WM4TEQQEAJ
# CLIENT_SECRET:THCXEARMB11F2KDNRUDU0GU35PKVT4MVFSP1CAJGWQET1CBP

# %% [markdown]
# ### Explore first neighbourhood in Data frame

# %%
# first neighbourhood
df_locations.loc[0, 'Address']
# Out:
# '산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea'

# %%
# lang, long of first neighbourhood
neighbourhood_latitude = df_locations.loc[0, 'Latitude'] # neighborhood latitude value
neighbourhood_longitude = df_locations.loc[0, 'Longitude'] # neighborhood longitude value

neighbourhood_name = df_locations.loc[0, 'Address'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of 산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea are 37.337181039087454, 127.02259953357414.

# %%
#Get Request URL
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius
 # create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=FQIQDSZ2JNHV2YB4MGT0DK4SAHODBFZHSLJY35WM4TEQQEAJ&client_secret=THCXEARMB11F2KDNRUDU0GU35PKVT4MVFSP1CAJGWQET1CBP&v=20190605&ll=37.337181039087454,127.02259953357414&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5dae9f88cf72a000397da32c'},
#  'response': {'warning': {'text': "There aren't a lot of results near you. Try something more general, reset your filters, or expand the search area."},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'totalResults': 3,
#   'suggestedBounds': {'ne': {'lat': 37.34168104358746,
#     'lng': 127.02824877904665},
#    'sw': {'lat': 37.33268103458745, 'lng': 127.01695028810163}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '514ec16ae4b08debeac5bc71',
#        'name': '광동농원',
#        'location': {'lat': 37.3358154296875,
#         'lng': 127.02411651611328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.3358154296875,
#           'lng': 127.02411651611328}],
#         'distance': 202,
#         'cc': 'KR',
#         'country': '대한민국',
#         'formattedAddress': ['대한민국']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-514ec16ae4b08debeac5bc71-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a5a3a6498e143ae4c59d42',
#        'name': '상광교마을회관',
#        'location': {'lat': 37.33890914916992,
#         'lng': 127.02594757080078,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.33890914916992,
#           'lng': 127.02594757080078}],
#         'distance': 353,
#         'cc': 'KR',
#         'country': '대한민국',
#         'formattedAddress': ['대한민국']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a5a3a6498e143ae4c59d42-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e59e482b993732579f02ead',
#        'name': '오리농장',
#        'location': {'lat': 37.334617614746094,
#         'lng': 127.01856231689453,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.334617614746094,
#           'lng': 127.01856231689453}],
#         'distance': 457,
#         'cc': 'KR',
#         'country': '대한민국',
#         'formattedAddress': ['대한민국']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e59e482b993732579f02ead-2'}]}]}}

# %%
# function that extracts the category of the venue (borrow from Foursquare)
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
#       name         categories        lat         lng
# 0     광동농원  Korean Restaurant  37.335815  127.024117
# 1  상광교마을회관        Bus Station  37.338909  127.025948
# 2     오리농장  Korean Restaurant  37.334618  127.018562

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 3 venues were returned by Foursquare.

# %% [markdown]
# ### Explore all the neighbourhoods around Samsung Digital City

# %%
#Let's create a function to repeat the same process to all the neighborhoods in Toronto
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#Create SDC Neighbourhoods venues using above function
SDC_venues = getNearbyVenues(names=df_locations['Address'],
                             latitudes=df_locations['Latitude'],
                             longitudes=df_locations['Longitude']
                             )
# Out:
# 산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 80 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 409-25 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 364-1 Pajang-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산121-1 Pajang-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 608 Pajang-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 46-15 Jeongja-ro 144beon-gil, Jeongja 1(il)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 870-2 Jeongja-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 922-1 Jeongja-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 723-5 Hwaseo 2(i)-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 463 Guun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 535-8 Guun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 209 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 140 Geumho-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1095-5 Homaesil-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1206-1 Homaesil-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 30-3 Cheoncheon-ri, Maesong-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 162-1 Cheoncheon-ri, Maesong-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 294-3 Cheoncheon-ri, Maesong-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 130-2 Sang-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# South Korea, Gyeonggi-do, Yongin-si, Suji-gu, Sinbong-dong, 116 광교산종루봉
# 산43-1 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산47-2 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 224-1 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산1-3 Jowon 2(i)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 18-1 Songjuk-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 75 Songjuk-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 242-1 Songjuk-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 23-14 Jeongja-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 48 Jeongjacheon-ro 134beon-gil, Jeongja 2(i)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 688-4 Hwaseo 2(i)-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 256-1 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 247-16 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 41 Hatap-ro 41beon-gil, Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 468 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 264-6 Homaesil-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# Seobu Public Garage, Pyeong-dong, Suwon, South Korea
# 1243-9 Homaesil-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 산11-2 Cheoncheon-ri, Maesong-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 435-2 Suyeong-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 56-2 Sang-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 산2 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산26 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 9-1 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 124 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 63-1 Jowon 2(i)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 506-17 Songjuk-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 36-3 Jeongja-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 74-37 Jeongja 2(i)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산43 Hwaseo 2(i)-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 223-18 Hwaseo 2(i)-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 345 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 149-10 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 507-2 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 540-82 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 633-112 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 173-2 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 360-7 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 407-1 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 113 Suyeong-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 576-1 Suyeong-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 산131-1 Sinbong-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산30 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산47 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산51-1 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 289-2 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 350 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 742-1 Jowon 1(il)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 783-14 Jowon 1(il)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 408-15 Yeonghwa-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 49 Jangan-ro 7beon-gil, Hwaseo-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 117-27 Hwaseo-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 14-26 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 61-3 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 685-1 Tap-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 887-22 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 885-42 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 141-11 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 422-1 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 206 Suyeong-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 15-5 Suyeong-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 산36 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산48 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 241-8 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 산78-2 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산74-2 Hagwanggyo-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 479-2 Jowon 1(il)-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 13 Gwanggyosan-ro, Yeonghwa-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 165-25 Yeonghwa-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 25 Hwaseomun-ro, Jangan-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 60-7 Hwaseo-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 141-71 Godeung-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 268-30 Godeung-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 329-5 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 72-1 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 986 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 67-3 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 465-3 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 130 Seosuwon-ro, Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 594-1 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 11-15 Donghwa-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 51-9 Donghwa-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 558-22 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 626 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산43-1 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1032-5 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 5-12 Yeonmu-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 30-7 World cup-ro 428beon-gil, Yeonmu-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 174-39 Yeonmu-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 350 Suwoncheon-ro, Haenggung-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 99-26 Haenggung-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 6-1 Maesanno 3(sam)-ga, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 13-15 Maesanno 2(i)-ga, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 18 Maesanno 1(il)-ga, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 21-6 Pyeong-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 185-8 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 259 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 667-2 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 454-2 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 798-7 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 333-18 Gibae-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 107 Donghwa-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 23-2 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산31 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 649 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 701-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 936-3 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산13 Yeonmu-dong, Jangan-gu, Suwon, Gyeonggi-do, South Korea
# 480-15 Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 220-5 Ji-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 313-17 Ji-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 31-1 Haenggung-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 86-2 Maegyo-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 89-36 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 203-7 Seryu 1(il)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 395-2 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 420 Pyeongni-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 205-4 Pyeongni-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 549 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 760-1 Omokcheon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 산16-4 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 925 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 203 Donghwa-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 420-1 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 500-1 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산22-3 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 506-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 807-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1171-1 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산7-5 Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 12 Paldalmun-ro 163beon-gil, Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 121-10 Jungbu-daero, Ji-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 258-1 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 899-1 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 138-122 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 526-5 Seryu 3(sam)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 546-8 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1039 Seryu 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 422-9 Jangji-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 334-3 Pyeongni-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 600 Gosaek-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 116-1 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 457-42 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 112-3 Wau-ri, Bongdam-eup, Hwaseong-si, Gyeonggi-do, South Korea
# 산66-6 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 810 Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산13-68 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산13-57 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 347-2 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 898-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산70 Uman-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 135-39 Uman 2(i)-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 303-62 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 951-6 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 941-7 Gwonseon 1(il)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 994-12 Gwonseon 1(il)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1114 Seryu-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 592-6 Seryu 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 99 Jangji-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# Jangji-dong, Gwonseon-gu, Suwon-si, Gyeonggi-do, South Korea
# 557 Jangji-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 50-3 Baeyang-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 69-377 Baeyang-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 457-467 Gian-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 188-224 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 192-12 Seongbok-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 780 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산63 Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 426 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# South Korea, Suwon, Woncheon-dong, 광교오드카운티
# 262-7 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산19-1 Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 29-52 Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 173-32 Maetan 1(il)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 165 Ingye-ro, Maetan 1(il)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1046-2 Ingye-dong, Paldal-gu, Suwon, Gyeonggi-do, South Korea
# 25 Gwonseon-ro 694beon-gil, Gwonseon 1(il)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1202 Gwonseon 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 384-7 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1174 Seryu 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 107 Jangji-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 335 Daehwanggyo-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 41-6 Baeyang-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 15-134 Gibae-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 15-241 Baeyang-dong, Hwaseong-si, Gyeonggi-do, South Korea
# South Korea, 경기도 화성시 효행로481번길 21 (안녕동)
# 768 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 산55-2 Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# Sanghyeon, Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 822 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 389-2 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산56 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산49-7 Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 130-25 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 916-1 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 946-6 Maetan 3(sam)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1166-1 Gwonseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1257-3 Gwonseon 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 289-1 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 230-5 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 257-8 Daehwanggyo-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 375-1 Daehwanggyo-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 산12 Hwanggye-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 171-143 Hwanggye-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 192-30 Songsan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 164-168 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 186-94 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 259 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 836 Sanghyeon-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 558 Sanghyeon 1(il)-dong, Suji-gu, Yongin-si, Gyeonggi-do, South Korea
# 220 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 331-16 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 740-4 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 658-3 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1197-2 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1217 Maetan 4(sa)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1252-1 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1279-1 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 1301 Gwonseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 1316-1 Gwonseon 2(i)-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 538-13 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# Hansol Apt., Hallim Library, Gokseon-dong, Suwon, South Korea
# 22-2 Daehwanggyo-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 138 Daehwanggyo-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 158-22 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산12 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 217 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산8-141 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# Sanghyeon LG Xi Apt., Sanghyeon-dong, Yongin-si, South Korea
# 산6-3 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산12-5 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 산29-3 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 510-11 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 599-1 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 623-3 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 465-6 Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 340-6 Maetan 3(sam)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 416 Maetan 3(sam)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 477-12 Taejang-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 609-2 Banjeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 112-3 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 183-2 Gokseon-dong, Gwonseon-gu, Suwon, Gyeonggi-do, South Korea
# 310-14 Banjeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 443-12 Banjeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 51-9030 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 109 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 135-200 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 50-16 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 105-54 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 910-4 Bojeong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 1064-7 Bojeong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산10-10 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 29-35 Ha-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 268-30 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 671-26 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 770 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 318-1 Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 296-25 Sinwon-ro, Woncheon-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 491-3 Maetan-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 401 Sin-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 38-8 Mangpo-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 72-7 Taejang-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 208-5 Taejang-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 242-2 Banjeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 364-1 Banjeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 692-90 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 23-2 Songsan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 119-146 Songsan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 71-417 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 988-3 Bojeong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산110 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 590 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 238-3 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산35-1 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 40-2 Yeongtong-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# South Korea, Gyeonggi-do, Suwon-si, Yeongtong-gu, 영통2동 맨발공원
# 972-2 Yeongtong-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# South Korea, Gyeonggi-do, Suwon-si, Yeongtong-gu, 덕영대로 경기도
# 245-10 Mangpo-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 668-7 Taejang-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 311-99 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 435-38 Gisan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 692-34 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 603 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 797 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 190 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 71-141 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 80-5 Annyeong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 502-18 Mabuk-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 311-2 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 357-1 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 518-2 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 64-1 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# Hwanggol Jugong, Byucksan Apt., Yeongtong-dong, Suwon, South Korea
# 956-1 Yeongtong-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# Bongyeong-ro, Yeongtong-dong, Yeongtong-gu, Suwon-si, Gyeonggi-do, South Korea
# 346 Maeyeong-ro, Yeongtong-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 143 Yeongtong 2(i)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 488 Mangpo-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 606-3 Mangpo-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# 199-2 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 220-5 Gisan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 3-9 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 866-6 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 523-6 Jinan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 655 Byeongjeom-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 1-22 Hwasan-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 138 Hanshindae-gil, Sema-dong, Osan, Gyeonggi-do, South Korea
# 419-2 Mabuk-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 145-7 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 384-45 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산49-8 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 242-1 Jungbu-daero, Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 129-62 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산44-1 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 1049-3 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, Gyeonggi-do, South Korea
# South Korea, Gyeonggi-do, Suwon-si, Yeongtong-gu, 영일로26 봉빌딩 401호
# 294-27 Seocheon-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 430-2 Seonong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 63-25 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 324-28 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 625-12 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# Chamnuri Apt., Gisan Middle School, Jinan-dong, Hwaseong-si, South Korea
# 21-1 Byeongjeom-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 127-2 Byeongjeom-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 410-4 Byeongjeom-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 11-2 Yangsan-dong, Osan, Gyeonggi-do, South Korea
# 125 Yangsan-dong, Osan, Gyeonggi-do, South Korea
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea
# 691 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 172 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 116-7 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 37-13 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 479-1 Singal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산6 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 345-87 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# South Korea, Gyeonggi-do, Yongin-si, Giheung-gu, 덕영대로 1871 105동 204호(하갈동, 청명호수마을신안인스빌1단지)
# 산75-1 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# South Korea, 경기도 용인시 기흥구 하갈동 덕영대로
# 200-12 Seonong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 306-58 Nongseo-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 354-7 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 486-4 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 1185 Dongtan 3(sam)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 165-2 Neung-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 228-5 Byeongjeom 2(i)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산25-1 Byeongjeom 2(i)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 506 Dongtan 3(sam)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산66-5 Segyo-dong, Osan, Gyeonggi-do, South Korea
# 산55 Segyo-dong, Osan, Gyeonggi-do, South Korea
# 147-8 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 271 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 429-2 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산16-3 Sanggal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 218-4 Sanggal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 349-1 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 129-2 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 434-5 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산80 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산123-3 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산27-3 Seocheon-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 278 Nongseo-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# Samsung 1ro 5-gil, Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산16 Banwol-dong, Hwaseong-si, Gyeonggi-do, South Korea
# Neung-dong Jugong Complex, Neung-dong, Hwaseong-si, South Korea
# 432-4 Neung-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 572-2 Neung-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 1039 Neung-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 558-1 Oesammi-dong, Osan, Gyeonggi-do, South Korea
# 329 Sema-dong, Osan, Gyeonggi-do, South Korea
# 26 Doksanseong-ro362beon-gil, Sema-dong, Osan, Gyeonggi-do, South Korea
# 132-44 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 184 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 480-6 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산10-12 Sanggal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 462-1 Sanggal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산8-8 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 140-5 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 83 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 499 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 7-2 Hagal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산17 Nongseo-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 211-3 Seonong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 36 Nongseo-ro 153beon-gil, Nongseo-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산25-2 Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산54 Seoku-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 26-5 Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 903 Dongtan 3(sam)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 997 Dongtan 3(sam)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 458-4 Oesammi-dong, Osan, Gyeonggi-do, South Korea
# 598-3 Oesammi-dong, Osan, Gyeonggi-do, South Korea
# 산12-4 Segyo-dong, Osan, Gyeonggi-do, South Korea
# 구갈동, 기흥구 용인시 경기도 South Korea
# 576 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산125-37 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산31-3 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 107 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 588-2 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 102 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 388-19 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 556 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 618-8 Gomae-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산88-2 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 182-1 Seonong-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 55-9 Seoku-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 234-4 Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 86-4 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 98 Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 119-5 Sema-dong, Osan, Gyeonggi-do, South Korea
# 289-21 Sema-dong, Osan, Gyeonggi-do, South Korea
# 산48 Oesammi-dong, Osan, Gyeonggi-do, South Korea
# 산69-3 Sinjang-dong, Osan, Gyeonggi-do, South Korea
# 165 Sucheong-ro, Geumam-dong, Osan, Gyeonggi-do, South Korea
# 산7-3 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 29 Gangnamdongro114Beon-gil, Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 649-5 Gugal-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산47 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 162-15 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 224 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 448-32 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 307-6 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 223-1 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 674-2 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 712-1 Gomae-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 764-1 Gomae-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 590-4 Dongtan 1(il)-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 376-6 Seoku-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 22-1 Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# South Korea, Hwaseong-si, Dongtan 2(i)-dong, 동탄2동행정복지센터
# 158-16 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 산37-2 Sema-dong, Osan, Gyeonggi-do, South Korea
# 365-1 Sinjang-dong, Osan, Gyeonggi-do, South Korea
# 652-13 Naesammi-dong, Osan, Gyeonggi-do, South Korea
# 산23 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 283-4 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산58-1 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 215-21 Saeun-ro, Jigok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산38-2 Jigok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 189-2 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 626-2 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 산27-4 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 200 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 409-100 Gomae-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 508-1 Gomae-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 120-38 Yeongcheon-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 358-20 Yeongcheon-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 505-4 Cheonggye-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 571 Seoku-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 124-2 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 518-2 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 178-1 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 279 Sinjang-dong, Osan, Gyeonggi-do, South Korea
# 260-1 Sinjang-dong, Osan, Gyeonggi-do, South Korea
# 567-2 Sinjang-dong, Osan, Gyeonggi-do, South Korea
# Dongbaek-dong Community Service Center, Jung-dong, Yongin-si, South Korea
# 산30 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 330-3 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 621 Sangha-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 436-13 Jigok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 687 Jigok-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 103 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 85-3 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 62-1 Gongse-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 368-18 Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 47-6 Wongomaero, Giheung-dong, Giheung-gu, Yongin-si, Gyeonggi-do, South Korea
# 79-9 Yeongcheon-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 506-11 Yeongcheon-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 425-27 Yeongcheon-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 124-1 Cheonggye-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 350 Cheonggye-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 824-3 Osan-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 606-1 Bansong-dong, Hwaseong-si, Gyeonggi-do, South Korea
# 171 Geumgok-ri, Dongtan-myeon, Hwaseong-si, Gyeonggi-do, South Korea
# 156-9 Naesammi-dong, Osan, Gyeonggi-do, South Korea
# 15-1 Naesammi-dong, Osan, Gyeonggi-do, South Korea

# %%
print(SDC_venues.shape)
SDC_venues.head()
# Out:
# (3139, 7)
#                                        Neighbourhood  Neighbourhood Latitude  \
# 0  산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeon...               37.337181
# 1  산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeon...               37.337181
# 2  산34 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeon...               37.337181
# 3  80 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeong...               37.332100
# 4  80 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeong...               37.332100
#
#    Neighbourhood Longitude    Venue  Venue Latitude  Venue Longitude  \
# 0               127.022600     광동농원       37.335815       127.024117
# 1               127.022600  상광교마을회관       37.338909       127.025948
# 2               127.022600     오리농장       37.334618       127.018562
# 3               127.018378    광교산입구       37.334322       127.017133
# 4               127.018378     폭포농원       37.334326       127.018045
#
#       Venue Category
# 0  Korean Restaurant
# 1        Bus Station
# 2  Korean Restaurant
# 3              Trail
# 4  Korean Restaurant

# %%
SDC_venues.groupby('Neighbourhood').count()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, ...                      10
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi...                       3
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-...                       8
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do,...                       6
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-d...                       4
# ...                                                                    ...
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-d...                       2
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea                            2
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeo...                       8
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeo...                       1
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gy...                       7
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, ...                       10
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi...                        3
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-...                        8
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do,...                        6
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-d...                        4
# ...                                                                     ...
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-d...                        2
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea                             2
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeo...                        8
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeo...                        1
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gy...                        7
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, ...     10              10
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi...      3               3
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-...      8               8
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do,...      6               6
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-d...      4               4
# ...                                                   ...             ...
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-d...      2               2
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea           2               2
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeo...      8               8
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeo...      1               1
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gy...      7               7
#
#                                                     Venue Longitude  \
# Neighbourhood
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, ...               10
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi...                3
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-...                8
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do,...                6
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-d...                4
# ...                                                             ...
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-d...                2
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea                     2
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeo...                8
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeo...                1
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gy...                7
#
#                                                     Venue Category
# Neighbourhood
# 1-1 Yeongtong 1(il)-dong, Yeongtong-gu, Suwon, ...              10
# 1-11 Bora-dong, Giheung-gu, Yongin-si, Gyeonggi...               3
# 1-68 Seodun-dong, Gwonseon-gu, Suwon, Gyeonggi-...               8
# 10-105 Annyeong-dong, Hwaseong-si, Gyeonggi-do,...               6
# 101-23 Jowon-dong, Jangan-gu, Suwon, Gyeonggi-d...               4
# ...                                                            ...
# 산86-4 Iui-dong, Yeongtong-gu, Suwon, Gyeonggi-d...               2
# 산89 Sema-dong, Osan, Gyeonggi-do, South Korea                    2
# 산95 Yeongdeok-dong, Giheung-gu, Yongin-si, Gyeo...               8
# 산99-6 Sanggwanggyo-dong, Jangan-gu, Suwon, Gyeo...               1
# 산99-7 Yeongdeok-dong, Giheung-gu, Yongin-si, Gy...               7
#
# [476 rows x 6 columns]

# %%
print('There are {} uniques categories.'.format(len(SDC_venues['Venue Category'].unique())))
# Out:
# There are 199 uniques categories.

# %%
#group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped.head()

# %% [markdown]
# ## End of document
